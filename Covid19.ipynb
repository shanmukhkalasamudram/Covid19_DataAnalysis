# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.

# %%
confirm = pd.read_csv("Datasets/covid19_Confirmed_dataset.csv")
confirm
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN         Western Sahara  24.215500 -12.885800        0
# 262            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 263            NaN                  Yemen  15.552727  48.516388        0
# 264            NaN                Comoros -11.645500  43.333300        0
# 265            NaN             Tajikistan  38.861034  71.276093        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  \
# ...

# %%
confirm.drop(["Lat","Long"],axis=1,inplace = True)

# %%
confirm.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
confirm_aggregated = confirm.groupby("Country/Region").sum()

# %%
confirm_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  4/21/20  \
# Country/Region                                           ...
# ...

# %%
confirm_aggregated.shape #187 countries
# Out:
# (187, 100)

# %%
 confirm_aggregated.loc["India"] #For particular country
# Out:
# 1/22/20        0
# 1/23/20        0
# 1/24/20        0
# 1/25/20        0
# 1/26/20        0
#            ...
# 4/26/20    27890
# 4/27/20    29451
# 4/28/20    31324
# 4/29/20    33062
# 4/30/20    34863
# Name: India, Length: 100, dtype: int64

# %%
confirm_aggregated.loc["India"].plot()

# %%
confirm_aggregated.loc["India"].plot()
confirm_aggregated.loc["China"].plot()
plt.legend() #Comparing Two countries

# %%
confirm_aggregated.loc["India"][:3].plot() #first three days, initial

# %%
confirm_aggregated.loc["India"].diff().plot()  #diff plot

# %%
confirm_aggregated.loc["India"].diff().max() # maximum for one country
# Out:
# 1893.0

# %%
countries = list(confirm_aggregated.index)
max_inf_rate = []
for c in countries:
    max_inf_rate.append(confirm_aggregated.loc[c].diff().max())
confirm_aggregated['max_inf_rate'] = max_inf_rate

# %%
confirm_aggregated.head() # max inflection rate for each country
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %%
corona_data = pd.DataFrame(confirm_aggregated["max_inf_rate"])

# %%
corona_data.head()  #only max inf rate
# Out:
#                 max_inf_rate
# Country/Region
# Afghanistan            232.0
# Albania                 34.0
# Algeria                199.0
# Andorra                 43.0
# Angola                   5.0

# %%
happy = pd.read_csv("Datasets/worldwide_happiness_report.csv")
happy
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
happy.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %%
happy.drop(["Overall rank","Score","Generosity","Perceptions of corruption"],axis=1,inplace = True)
happy.head(10)  #removing unneccesary columns
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
# 5       Switzerland           1.452           1.526                    1.052
# 6            Sweden           1.387           1.487                    1.009
# 7       New Zealand           1.303           1.557                    1.026
# 8            Canada           1.365           1.505                    1.039
# 9           Austria           1.376           1.475                    1.016
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# ...

# %%
happy.set_index("Country or region",inplace=True)

# %%
happy.head(10)
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
# Switzerland                 1.452           1.526                    1.052
# Sweden                      1.387           1.487                    1.009
# New Zealand                 1.303           1.557                    1.026
# Canada                      1.365           1.505                    1.039
# Austria                     1.376           1.475                    1.016
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# ...

# %%
# join two data sets

# %%
corona_data.head()
# Out:
#                 max_inf_rate
# Country/Region
# Afghanistan            232.0
# Albania                 34.0
# Algeria                199.0
# Andorra                 43.0
# Angola                   5.0

# %%
corona_data.shape
# Out:
# (187, 1)

# %%
happy.shape
# Out:
# (156, 4)

# %%
d= corona_data.join(happy,how="inner")  # perfoming inner join to include all 
d
# Out:
#              max_inf_rate  GDP per capita  Social support  \
# Afghanistan         232.0           0.350           0.517
# Albania              34.0           0.947           0.848
# Algeria             199.0           1.002           1.160
# Argentina           291.0           1.092           1.432
# Armenia             134.0           0.850           1.055
# ...                   ...             ...             ...
# Venezuela            29.0           0.960           1.427
# Vietnam              19.0           0.741           1.346
# Yemen                 5.0           0.287           1.163
# Zambia                9.0           0.578           1.058
# Zimbabwe              8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# ...

# %%
# now to compaer and analysis we perform corelation matrix

# %%
d.corr()
# Out:
#                               max_inf_rate  GDP per capita  Social support  \
# max_inf_rate                      1.000000        0.250118        0.191958
# GDP per capita                    0.250118        1.000000        0.759468
# Social support                    0.191958        0.759468        1.000000
# Healthy life expectancy           0.289263        0.863062        0.765286
# Freedom to make life choices      0.078196        0.394603        0.456246
#
#                               Healthy life expectancy  \
# max_inf_rate                                 0.289263
# GDP per capita                               0.863062
# Social support                               0.765286
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.427892
#
#                               Freedom to make life choices
# max_inf_rate                                      0.078196
# GDP per capita                                    0.394603
# ...

# %%
d.head()
# Out:
#              max_inf_rate  GDP per capita  Social support  \
# Afghanistan         232.0           0.350           0.517
# Albania              34.0           0.947           0.848
# Algeria             199.0           1.002           1.160
# Argentina           291.0           1.092           1.432
# Armenia             134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
#gdp vs max inf rate

# %%
y = d["max_inf_rate"]
x = d["GDP per capita"]
sns.scatterplot(x,y)

# %%
y = d["max_inf_rate"]
x = d["GDP per capita"]
sns.scatterplot(x, np.log(y))              # for closer observation

# %%
sns.regplot(x, np.log(y))

# %%
# result : people in developed countires are more prone of getting disease
